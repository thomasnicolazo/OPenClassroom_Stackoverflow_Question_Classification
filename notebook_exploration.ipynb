# %% [markdown]
# # Tags Indicator for StackOverflow

# %% [markdown]
# ## Introduction

# %%
import os
import time
import re
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import nltk
import spacy
nltk.download('stopwords')
import unidecode
import pickle
from bs4 import BeautifulSoup as bs
# Out:
# [nltk_data] Downloading package stopwords to /home/thomas/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from IPython.display import display,HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 200)
pd.set_option("display.max_colwidth",200)
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
path = '/home/thomas/Documents/openclassroom/projet5/'

# %%
os.listdir(path)
# Out:
# ['cleanDataprepSmote.pickle',
#  'BOW.ipynb',
#  'BOW_RF_reduced',
#  'SQLQuery2',
#  'clean_data.csv',
#  'Untitled1.ipynb',
#  'Doc2Vec.ipynb',
#  'W2V_logistic_reduced',
#  'cleanDataprepSmote2.pickle',
#  'notebook_exploration.ipynb',
#  'BOW_RF_original',
#  'W2V_RF_reduced',
#  'BOW_SVC_original',
#  'QueryResults2.csv',
#  'BOW_logistic_reduced',
#  '.ipynb_checkpoints',
#  'Untitled.ipynb',
#  'Exemple_Tweets_Feature-extraction_Sentence+Embedding_V1.1.ipynb',
#  'QueryResults.csv',
#  'BOW_SVC_reduced',
#  'cleanData.pickle',
#  'BOW_logistic_original']

# %%
data = pd.read_csv(path + 'QueryResults2.csv')

# %%
display(data.columns)
# Out:
# Index(['Title', 'Body', 'Tags'], dtype='object')

# %%
data = data.loc[:, ['Title','Body','Tags']]

# %%
data.head()
# Out:
#                                                                     Title  \
# 0                                  Django m2m form save " through " table
# 1                              Transpose/Unzip Function (inverse of zip)?
# 2                           Detecting audio silence in WAV files using C#
# 3                                     How to request a random row in SQL?
# 4  mod_rewrite rule to redirect all requests except for one specific path
#
#                                                                                                                                                                                                       Body  \
# 0  <p>I'm having trouble in saving a m2m data, containing a 'through' class table.\nI want to save all selected members (selected in the form) in the through table.\nBut i don't know how to initialis...
# 1  <p>I have a list of 2-item tuples and I'd like to convert them to 2 lists where the first contains the first item in each tuple and the second list holds the second item.</p>\n\n<p><strong>For exa...
# 2  <p>I'm tasked with building a .NET client app to detect silence in a WAV files.</p>\n\n<p>Is this possible with the built-in Windows APIs? Or alternately, any good libraries out there to help with...
# 3                                                                                                        <p>How can I request a random row (or as close to truly random as is possible) in pure SQL?</p>\n
# 4  <p>I'm trying to redirect all requests to my domain to another domain using mod_rewrite in an Apache 2.2 VirtualHost declaration. There is one exception to this -- I'd like all requests  to the <c...
#
#                                 Tags
# 0               <django><forms><m2m>
# 1  <python><list><matrix><transpose>
# 2                  <c#><.net><audio>
# 3                      <sql><random>
# 4              <apache><mod-rewrite>

# %% [markdown]
# ### exploration

# %%
data.loc[0,'Body']
# Out:
# '<p>I\'m having trouble in saving a m2m data, containing a \'through\' class table.\nI want to save all selected members (selected in the form) in the through table.\nBut i don\'t know how to initialise the \'through\' table in the view.</p>\n\n<p>my code:</p>\n\n<pre><code>class Classroom(models.Model):\n     user = models.ForeignKey(User, related_name = \'classroom_creator\')\n     classname = models.CharField(max_length=140, unique = True)\n     date = models.DateTimeField(auto_now=True)\n     open_class = models.BooleanField(default=True)\n     members = models.ManyToManyField(User,related_name="list of invited members", through = \'Membership\')\n\nclass Membership(models.Model): \n      accept = models.BooleanField(User)\n      date = models.DateTimeField(auto_now = True) \n      classroom = models.ForeignKey(Classroom, related_name = \'classroom_membership\')\n      member = models.ForeignKey(User, related_name = \'user_membership\')\n</code></pre>\n\n<p>and in the view:</p>\n\n<pre><code>def save_classroom(request):\n   classroom_instance = Classroom()\n   if request.method == \'POST\':\n        form = ClassroomForm(request.POST, request.FILES, user = request.user) \n        if form.is_valid():\n           new_obj = form.save(commit=False)\n           new_obj.user = request.user \n           new_obj.save()\n           membership = Membership(member = HERE SELECTED ITEMS FROM FORM,classroom=new_obj)\n\n           membership.save() \n</code></pre>\n\n<p>How should I initialise the membership for the Membership table to be populated right?</p>\n'

# %%
data.isna().any()
# Out:
# Title    False
# Body     False
# Tags     False
# dtype: bool

# %%
display(data['Body'])
# Out:
# 0        <p>I'm having trouble in saving a m2m data, containing a 'through' class table.\nI want to save all selected members (selected in the form) in the through table.\nBut i don't know how to initialis...
# 1        <p>I have a list of 2-item tuples and I'd like to convert them to 2 lists where the first contains the first item in each tuple and the second list holds the second item.</p>\n\n<p><strong>For exa...
# 2        <p>I'm tasked with building a .NET client app to detect silence in a WAV files.</p>\n\n<p>Is this possible with the built-in Windows APIs? Or alternately, any good libraries out there to help with...
# 3                                                                                                              <p>How can I request a random row (or as close to truly random as is possible) in pure SQL?</p>\n
# 4        <p>I'm trying to redirect all requests to my domain to another domain using mod_rewrite in an Apache 2.2 VirtualHost declaration. There is one exception to this -- I'd like all requests  to the <c...
#                                                                                                           ...
# 49995    <p>I am new to git. I have a very simple scenario for using git. I had my first release written with Android Studio. Now I want to work with some new features. What I did so far:</p>\n\n<ol>\n<li>...
# 49996    <p>Let's say I have three certificates (in Base64 format)</p>\n\n<pre><code>Root\n |\n --- CA\n     |\n     --- Cert (client/signing/whatever)\n</code></pre>\n\n<p>How can I validate the certs and...
# 49997    <p>Why is <code>&amp;&amp;</code> preferable to <code>&amp;</code> and <code>||</code> preferable to <code>|</code>?</p>\n\n<p>I asked someone who's been programming for years and his explanation ...
# 49998    <p>I have a huge numpy 3D tensor which is stored in a file on my disk (which I normally read using <code>np.load</code>). This is a binary <code>.npy</code> file. On using <code>np.load</code>, I ...
# 49999    <p>I'm new to Android and socket programming. I want to create an android application that transfer video live from device camera to PC. What first i do is to get a raw video data from PreviewCall...
# Name: Body, Length: 50000, dtype: object

# %%
display(data.loc[2,'Body'])
display(data.loc[27953,'Body'])
# Out:
# "<p>I'm tasked with building a .NET client app to detect silence in a WAV files.</p>\n\n<p>Is this possible with the built-in Windows APIs? Or alternately, any good libraries out there to help with this?</p>\n"
# '<p>I want to be able to list the items that either a user has added (they are listed as the creator) or the item has been approved.</p>\n\n<p>So I basically need to select:</p>\n\n<pre><code>item.creator = owner or item.moderated = False\n</code></pre>\n\n<p>How would I do this in Django? (preferably with a filter or queryset).</p>\n'

# %%
display(data['Title'])
# Out:
# 0                                        Django m2m form save " through " table
# 1                                    Transpose/Unzip Function (inverse of zip)?
# 2                                 Detecting audio silence in WAV files using C#
# 3                                           How to request a random row in SQL?
# 4        mod_rewrite rule to redirect all requests except for one specific path
#                                           ...
# 49995                                 How to use git branch with Android Studio
# 49996            C# How can I validate a Root-CA-Cert certificate (x509) chain?
# 49997                                                     Why '&&' and not '&'?
# 49998                         Efficient way to partially read large numpy file?
# 49999                          Creating RTP Packets from Android Camera to Send
# Name: Title, Length: 50000, dtype: object

# %% [markdown]
# ### HTML elements in body

# %%
sampleHtml = data.loc[2,'Body']
soup = bs(sampleHtml, 'html.parser')
print(soup.prettify())
# Out:
# <p>
#  I'm tasked with building a .NET client app to detect silence in a WAV files.
# </p>
# <p>
#  Is this possible with the built-in Windows APIs? Or alternately, any good libraries out there to help with this?
# </p>

# %%
[i for i in soup.descendants]
# Out:
# [<p>I'm tasked with building a .NET client app to detect silence in a WAV files.</p>,
#  "I'm tasked with building a .NET client app to detect silence in a WAV files.",
#  '\n',
#  <p>Is this possible with the built-in Windows APIs? Or alternately, any good libraries out there to help with this?</p>,
#  'Is this possible with the built-in Windows APIs? Or alternately, any good libraries out there to help with this?',
#  '\n']

# %%
[tag.name for tag in soup.find_all(True)]
# Out:
# ['p', 'p']

# %%
soup.find_all('p')
# Out:
# [<p>I'm tasked with building a .NET client app to detect silence in a WAV files.</p>,
#  <p>Is this possible with the built-in Windows APIs? Or alternately, any good libraries out there to help with this?</p>]

# %% [markdown]
# count occurence HTML elements in data

# %% [raw]
# startTime = time.time()
# dataBody = data.loc[:,'Body']
# array = np.array([])
# for parag in dataBody:
#     soup = bs(parag, 'html.parser')
#     tagList = [tag.name for tag in soup.find_all(True)]
#     array = np.append(array, np.array(tagList))
#
# dfHTMLElem  = pd.DataFrame(array,)
# endTime = time.time()
# print(f"Execution Time {endTime - startTime} s")

# %% [raw]
# dfHTMLElem.value_counts()

# %% [raw]
# dfHTMLElem.value_counts().plot(kind='barh').set_title('count HTML Elements')

# %% [raw]
# del dfHTMLElem

# %% [markdown]
# test get_text from beatifulSoup as a solution to extract text from HTML elements.

# %% [markdown]
# ## HTML processing

# %%
soup = bs(sampleHtml, 'html.parser')
soup.get_text()
# Out:
# "I'm tasked with building a .NET client app to detect silence in a WAV files.\nIs this possible with the built-in Windows APIs? Or alternately, any good libraries out there to help with this?\n"

# %% [markdown]
# ## Lower text and count characters in text body

# %% [markdown]
# add 2 columns to data with the lowered text processed by beautiful soup and the number of characters in the text processed by beautiful soup.

# %%
dataText = data.loc[:,'Body'].apply(lambda x: bs(x,'html.parser').get_text())
dataText = dataText.apply(lambda x : x.lower())
data['Title'] = data['Title'].apply(lambda x : x.lower())
dataText2 = pd.DataFrame({'text':dataText})
dataText2['nb_char'] = distriChar = dataText2['text'].apply(lambda x : len(x))
data['text'] = dataText
data['nb_char'] = distriChar

# %%
sns.displot(data = distriChar,height=9).set(title='characters distribution in posts')

# %%
sns.displot(data = distriChar[distriChar > 100],height=9).set(title='characters distribution for posts with more than 100 characters')

# %%
sns.displot(data = distriChar[distriChar < 100],height=9).set(title='characters distribution for posts with less than 100 characters')

# %% [markdown]
# Beware of outliers!

# %%
distriChar.describe(percentiles=[.01,.02,.05,.95,.98,.99])
# Out:
# count    50000.00000
# mean       807.35788
# std       1135.91375
# min         11.00000
# 1%          61.00000
# 2%          75.00000
# 5%         114.00000
# 50%        503.00000
# 95%       2388.05000
# 98%       3759.00000
# 99%       5229.08000
# max      28545.00000
# Name: text, dtype: float64

# %%
display(dataText2[dataText2['nb_char']< 75])
# Out:
#                                                                             text  \
# 41                       what's the most efficient way to concatenate strings?\n
# 67           how do i go about specifying and using an enum in a django model?\n
# 78                              what are your favorite (g)vim plugins/scripts?\n
# 107            where can i get some decent looking free asp.net or css themes?\n
# 112                       how do you calculate the distance between 2 cities? \n
# ...                                                                          ...
# 49410          data.table has introduced the := operator. why not overload <-?\n
# 49560    how do i build boost's iostreams library with gzip and bzip2 support?\n
# 49706               what is the difference between git clone and git checkout?\n
# 49865                      what is the complexity of the log base 10 function?\n
# 49894  why does the indexing in an array  start with zero in c and not with 1?\n
#
#        nb_char
# 41          54
# 67          66
# 78          47
# 107         64
# 112         53
# ...        ...
# 49410       64
# 49560       70
# 49706       59
# 49865       52
# 49894       72
#
# [978 rows x 2 columns]

# %%
display(dataText2[dataText2['nb_char']> 25000])
# Out:
#                                                                                                                                                                                                           text  \
# 8523   we are using a 3 site, 3 nodes per site cassandra 1.1.12 cluster that has 8gb ram allocated per node.  we have been seeing long gc pauses on nodes periodically and that is messing with our applica...
# 30463  i tried a lot but can´t find it out, so i hope you can help me.\ni am trying to build my own voice recognition app, which doesn´t show up the dialog.\ni already wrote some code and it works quite ...
# 35006  i haven't updated anything for at least a month.  i was just working normally and suddenly the menus were all blank, so i decided to restart eclipse. i clicked "close" and "ok" to save everything,...
# 39181  this will apply mostly for an asp.net application where the data is not accessed via soa. meaning that you get access to the objects loaded from the framework, not transfer objects, although some ...
# 39262  i am using stackdumps with win32, to write all return adresses into my logfile. i match these with a mapfile later on (see my article [post mortem debugging][1]). \nedit:: problem solved - see my ...
#
#        nb_char
# 8523     28545
# 30463    28237
# 35006    26633
# 39181    28533
# 39262    28119

# %%
dataText2.loc[8523,'text']
# Out:
# "we are using a 3 site, 3 nodes per site cassandra 1.1.12 cluster that has 8gb ram allocated per node.  we have been seeing long gc pauses on nodes periodically and that is messing with our applications realtime requirements.  the systems we run on are 8 core systems with 24gb of ram.\nwe've been seeing 120+ second pauses where it does a stop the world gc.  \nwe are running with these flags on jdk 1.7.0_04\n-xx:+usethreadpriorities \n-xx:threadprioritypolicy=42 \n-xms8g \n-xmx8g \n-xmn1600m \n-xx:+heapdumponoutofmemoryerror \n-xss180k \n-xx:+useparnewgc \n-xx:+useconcmarksweepgc \n-xx:+cmsparallelremarkenabled \n-xx:survivorratio=8 \n-xx:maxtenuringthreshold=1 \n-xx:cmsinitiatingoccupancyfraction=75 \n-xx:+usecmsinitiatingoccupancyonly \n-xx:+printgcdetails \n-xx:+printgcdatestamps \n-xx:+printheapatgc \n-xx:+printtenuringdistribution \n-xx:+printgcapplicationstoppedtime \n-xx:+printpromotionfailure \n-xx:printflsstatistics=1 \n\nhere is the detailed gc log leading up to the long pause:\n\n\n2014-02-23t11:50:19.231-0500: 2119627.980: [gc before gc:\nstatistics for binarytreedictionary:\n------------------------------------\ntotal free space: 145905916\nmax   chunk size: 3472057\nnumber of blocks: 160577\nav.  block  size: 908\ntree      height: 146\nbefore gc:\nstatistics for binarytreedictionary:\n------------------------------------\ntotal free space: 0\nmax   chunk size: 0\nnumber of blocks: 0\ntree      height: 0\n2119627.981: [parnew\ndesired survivor size 83886080 bytes, new threshold 1 (max 1)\n- age   1:   32269664 bytes,   32269664 total\n: 1356995k->44040k(1474560k), 4.5270760 secs] 5829345k->4546031k(8224768k)after gc:\nstatistics for binarytreedictionary:\n------------------------------------\ntotal free space: 144857324\nmax   chunk size: 2423465\nnumber of blocks: 160577\nav.  block  size: 902\ntree      height: 146\nafter gc:\nstatistics for binarytreedictionary:\n------------------------------------\ntotal free space: 0\nmax   chunk size: 0\nnumber of blocks: 0\ntree      height: 0\n, 4.5295190 secs] [times: user=24.78 sys=0.07, real=4.52 secs] \nheap after gc invocations=82068 (full 2561):\n par new generation   total 1474560k, used 44040k [0x00000005fae00000, 0x000000065ee00000, 0x000000065ee00000)\n  eden space 1310720k,   0% used [0x00000005fae00000, 0x00000005fae00000, 0x000000064ae00000)\n  from space 163840k,  26% used [0x000000064ae00000, 0x000000064d902028, 0x0000000654e00000)\n  to   space 163840k,   0% used [0x0000000654e00000, 0x0000000654e00000, 0x000000065ee00000)\n concurrent mark-sweep generation total 6750208k, used 4501991k [0x000000065ee00000, 0x00000007fae00000, 0x00000007fae00000)\n concurrent-mark-sweep perm gen total 40012k, used 23966k [0x00000007fae00000, 0x00000007fd513000, 0x0000000800000000)\n}\ntotal time for which application threads were stopped: 4.5524690 seconds\n{heap before gc invocations=82068 (full 2561):\n par new generation   total 1474560k, used 1354760k [0x00000005fae00000, 0x000000065ee00000, 0x000000065ee00000)\n  eden space 1310720k, 100% used [0x00000005fae00000, 0x000000064ae00000, 0x000000064ae00000)\n  from space 163840k,  26% used [0x000000064ae00000, 0x000000064d902028, 0x0000000654e00000)\n  to   space 163840k,   0% used [0x0000000654e00000, 0x0000000654e00000, 0x000000065ee00000)\n concurrent mark-sweep generation total 6750208k, used 4501991k [0x000000065ee00000, 0x00000007fae00000, 0x00000007fae00000)\n concurrent-mark-sweep perm gen total 40012k, used 23966k [0x00000007fae00000, 0x00000007fd513000, 0x0000000800000000)\n2014-02-23t11:51:14.221-0500: 2119682.970: [gc before gc:\nstatistics for binarytreedictionary:\n------------------------------------\ntotal free space: 144857324\nmax   chunk size: 2423465\nnumber of blocks: 160577\nav.  block  size: 902\ntree      height: 146\nbefore gc:\nstatistics for binarytreedictionary:\n------------------------------------\ntotal free space: 0\nmax   chunk size: 0\nnumber of blocks: 0\ntree      height: 0\n2119682.971 ...

# %%
data = data[(data['nb_char'] >= data['nb_char'].quantile(0.02)) & (data['nb_char'] <= data['nb_char'].quantile(0.98))] # remove too small questions and too big questions
print(f'data shape after removing : {data.shape}')
# Out:
# data shape after removing : (48023, 5)

# %%
data.head()
# Out:
#                                                                     Title  \
# 0                                  django m2m form save " through " table
# 1                              transpose/unzip function (inverse of zip)?
# 2                           detecting audio silence in wav files using c#
# 3                                     how to request a random row in sql?
# 4  mod_rewrite rule to redirect all requests except for one specific path
#
#                                                                                                                                                                                                       Body  \
# 0  <p>I'm having trouble in saving a m2m data, containing a 'through' class table.\nI want to save all selected members (selected in the form) in the through table.\nBut i don't know how to initialis...
# 1  <p>I have a list of 2-item tuples and I'd like to convert them to 2 lists where the first contains the first item in each tuple and the second list holds the second item.</p>\n\n<p><strong>For exa...
# 2  <p>I'm tasked with building a .NET client app to detect silence in a WAV files.</p>\n\n<p>Is this possible with the built-in Windows APIs? Or alternately, any good libraries out there to help with...
# 3                                                                                                        <p>How can I request a random row (or as close to truly random as is possible) in pure SQL?</p>\n
# 4  <p>I'm trying to redirect all requests to my domain to another domain using mod_rewrite in an Apache 2.2 VirtualHost declaration. There is one exception to this -- I'd like all requests  to the <c...
#
#                                 Tags  \
# 0               <django><forms><m2m>
# 1  <python><list><matrix><transpose>
# 2                  <c#><.net><audio>
# 3                      <sql><random>
# 4              <apache><mod-rewrite>
#
#                                                                                                                                                                                                       text  \
# 0  i'm having trouble in saving a m2m data, containing a 'through' class table.\ni want to save all selected members (selected in the form) in the through table.\nbut i don't know how to initialise t...
# 1  i have a list of 2-item tuples and i'd like to convert them to 2 lists where the first contains the first item in each tuple and the second list holds the second item.\nfor example:\noriginal = [(...
# 2         i'm tasked with building a .net client app to detect silence in a wav files.\nis this possible with the built-in windows apis? or alternately, any good libraries out there to help with this?\n
# 3                                                                                                               how can i request a random row (or as close to truly random as is possible) in pure sql?\n
# 4  i'm trying to redirect all requests to my domain to another domain using mod_rewrite in an apache 2.2 virtualhost declaration. there is one exception to this -- i'd like all requests  to the /audi...
#
#    nb_char
# 0     1442
# 1      350
# 2      190
# 3       89
# 4     1990

# %%
data['text'].sample(10)
# Out:
# 5992     i'm trying to convert the data from a simple object graph into a dictionary. i don't need type information or methods and i don't need to be able to convert it back to an object again. \ni found t...
# 32842    i am working on a django project for racing event in which a table in the database has three fields.\n1)boolean field to know whether race is active or not\n2)race start time\n3)race end time\nwhi...
# 14338                                                                       i want to get the build status in tfs (whether it is succeeded or failed). which classes and methods can be used for this purpose?\n
# 32245    in java for string class there is a method called matches, how to use this method to check if my string is having only digits using regular expression. i tried with below examples, but both of the...
# 49571    let's say i have two similar types set this way :\ntype type1 []struct {\n    field1 string\n    field2 int\n}\ntype type2 []struct {\n    field1 string\n    field2 int\n}\n\nis there a direct way...
# 33717    i have a table on pgsql with names (having more than 1 mio. rows), but i have also many duplicates. i select 3 fields: id, name, metadata.\ni want to select them randomly with order by random() an...
# 27070                                                          i would like to know from the experienced programmers what they consider to be the most important considerations when designing a new database.\n
# 31419    is there a way to build tests with sbt without running them?\nmy own use case is to run static analysis on the test code by using a scalac plugin. another possible use case is to run some or all o...
# 39966    in javascript, how would you check if an element is actually visible?\ni don't just mean checking the visibility and display attributes. i mean, checking that the element is not\n\nvisibility: hid...
# 5756     are there any preexisting maven plugins or commands to update the dependencies in the pom? \nexample: (if this was in my pom)\n<dependency>\n    <groupid>commons-lang</groupid>\n    <artifactid>co...
# Name: text, dtype: object

# %% [markdown]
# ### Text is ascii ?

# %%
data.loc[:,'text'].apply(lambda x: x.isascii()).any()
# Out:
# True

# %% [markdown]
# The text column contains only ascii characters.

# %% [markdown]
# ## tokenize text and count tokens

# %%
tokenizerText = nltk.RegexpTokenizer(r'([A-Za-z0-9+#]+)')
dataTokens = data['text'].apply(lambda x : tokenizerText.tokenize(x))
dataTitle = data['Title'].apply(lambda x : tokenizerText.tokenize(x))
data['tokens'] = dataTokens
data['tokens_title'] = dataTitle
data['nb_tokens'] = dataTokens.apply(lambda x: len(x))
dataTokensUniq = dataTokens.apply(lambda x : tuple(set(x)))
data['tokens_unique'] = dataTokensUniq
data['nb_tokens_unique'] = dataTokensUniq.apply(lambda x: len(x))

# %%
display(dataTokens)
# Out:
# 0        [i, m, having, trouble, in, saving, a, m2m, data, containing, a, through, class, table, i, want, to, save, all, selected, members, selected, in, the, form, in, the, through, table, but, i, don, t,...
# 1        [i, have, a, list, of, 2, item, tuples, and, i, d, like, to, convert, them, to, 2, lists, where, the, first, contains, the, first, item, in, each, tuple, and, the, second, list, holds, the, second...
# 2        [i, m, tasked, with, building, a, net, client, app, to, detect, silence, in, a, wav, files, is, this, possible, with, the, built, in, windows, apis, or, alternately, any, good, libraries, out, the...
# 3                                                                                                      [how, can, i, request, a, random, row, or, as, close, to, truly, random, as, is, possible, in, pure, sql]
# 4        [i, m, trying, to, redirect, all, requests, to, my, domain, to, another, domain, using, mod, rewrite, in, an, apache, 2, 2, virtualhost, declaration, there, is, one, exception, to, this, i, d, lik...
#                                                                                                           ...
# 49995    [i, am, new, to, git, i, have, a, very, simple, scenario, for, using, git, i, had, my, first, release, written, with, android, studio, now, i, want, to, work, with, some, new, features, what, i, d...
# 49996    [let, s, say, i, have, three, certificates, in, base64, format, root, ca, cert, client, signing, whatever, how, can, i, validate, the, certs, and, certificate, path, chain, in, c#, all, those, thr...
# 49997    [why, is, preferable, to, and, preferable, to, i, asked, someone, who, s, been, programming, for, years, and, his, explanation, was, for, example, in, if, bool1, bool2, bool3, dosomething, bool1, ...
# 49998    [i, have, a, huge, numpy, 3d, tensor, which, is, stored, in, a, file, on, my, disk, which, i, normally, read, using, np, load, this, is, a, binary, npy, file, on, using, np, load, i, quickly, end,...
# 49999    [i, m, new, to, android, and, socket, programming, i, want, to, create, an, android, application, that, transfer, video, live, from, device, camera, to, pc, what, first, i, do, is, to, get, a, raw...
# Name: text, Length: 48023, dtype: object

# %% [raw]
# tokenizerTags = nltk.RegexpTokenizer(r'\w+')
# tokenTags = data['Tags'].apply(lambda x: tokenizerTags.tokenize(x))
# lenTokenTags = tokenTags.apply(lambda x: len(x))

# %% [raw]
# tokenTags

# %% [raw]
# plt.figure(figsize=(12,12))
# plt.scatter(lenTokenTags, data['nb_tokens_unique'])
# plt.xlabel('number of tags')
# plt.ylabel('number of unique tokens in the text')
# plt.title('number of tags versus number of unique tokens in texts')
# plt.show()

# %% [markdown]
# ### words frequency anaylsis

# %% [markdown]
# check the word frequency in corpus

# %%
##TEST
freq_totale = nltk.Counter(['a','b','c','c'])
print(freq_totale)
# Out:
# Counter({'c': 2, 'a': 1, 'b': 1})

# %%
def wordFrequency(data):
    ''' take pandas series and count words retun the occurences of the elements'''
    freqTotal = {}
    for text in data:
        freq = nltk.Counter(text)
        for word, count in freq.items():
            if word in freqTotal.keys():
                freqTotal[word] += count
            else:
                freqTotal[word] = count
    return freqTotal

# %%
freqWord = wordFrequency(data['tokens_unique'])
dataFreqWord = pd.DataFrame({'word':freqWord.keys(),'count':freqWord.values()})

# %%
#print(freq)

# %%
dataFreqWord[dataFreqWord['count']>10000]
# Out:
#       word  count
# 3       if  16311
# 4       be  17956
# 10    want  11377
# 13       m  13657
# 15     how  18696
# 17    code  11149
# 20      is  35278
# 34      my  17760
# 40     and  32815
# 45     for  24748
# 51      in  33311
# 56      of  28836
# 58     but  23139
# 59     the  42299
# 65    from  13970
# 68      to  42290
# 76       t  16246
# 80       a  38816
# 81       i  43503
# 82    have  22146
# 96   there  16466
# 99    that  25716
# 106   like  15280
# 118   this  27658
# 121    any  12205
# 128     or  15322
# 131   with  19472
# 137    can  20881
# 141     as  14708
# 153   what  16903
# 156      s  13447
# 169   when  11836
# 173     do  17475
# 189     an  16071
# 192  using  14224
# 213     it  28022
# 219  would  11392
# 223     on  17795
# 228    are  13201
# 231    not  17271
# 241   some  10364
# 257    get  10763
# 283  which  10480
# 285    use  12604
# 289     so  13786
# 409    way  11993
# 620     am  10950

# %%
#sns.displot(data=dataFreqWord.sample(1000), x="count")

# %%
plt.figure(figsize=(12,12))
dataFreqWordSorted = dataFreqWord['count'].sort_values()
dataFreqWordSorted =dataFreqWordSorted[dataFreqWordSorted >1000]
plt.scatter(x=dataFreqWordSorted.index, y=dataFreqWordSorted)
plt.plot(dataFreqWordSorted.index, np.linspace(15000,15000,len(dataFreqWordSorted.index)),'r-')
plt.plot(dataFreqWordSorted.index, np.linspace(10000,10000,len(dataFreqWordSorted.index)),'g-')
plt.xlabel('indexes')
plt.ylabel('frequency')
plt.title(' frequency in corpus')
plt.legend(('data frequency', 'threshold frequency 15000', 'threshold frequency 10000'),
           loc='upper right', shadow=True)
plt.show()

# %% [markdown]
# len(dataFreqWordSorted)The high frequency words correspond to the common english language. We need to get rid of them to have only the important features left. The best threshold to cut the high frequency word seems to be 10000.

# %%
len(dataFreqWordSorted) # nb of words used in the the posts. it's weird that the  number is so low
# Out:
# 518

# %%
len(dataFreqWordSorted[dataFreqWordSorted>10000])/len(dataFreqWordSorted)
# Out:
# 0.09073359073359073

# %% [markdown]
# approximately 10% of the word are Stop words

# %% [markdown]
# ## Delete Stop Words

# %%
#delete high frequency words, common english words and numerical values
threshold =np.quantile(dataFreqWordSorted,0.9)
sw = set(dataFreqWordSorted[dataFreqWordSorted>threshold])
sw.update(tuple(nltk.corpus.stopwords.words('english')))

# %%
def removeSW(dataTokens):
    final = [[word for word in ListTokens if word not in sw and not word.isnumeric()]
                for ListTokens in dataTokens]
    return final

# %%
tokenWithoutSW = removeSW(data['tokens'])
tokenTitleWithoutSW = removeSW(data['tokens_title'])
data['tokens_WSW'] = tokenWithoutSW
data['tokens_title_WSW'] = tokenTitleWithoutSW
data['nb_tokens_WSW'] = data['tokens_WSW'].apply(lambda x: len(x))

# %%
data.head()
# Out:
#                                                                     Title  \
# 0                                  django m2m form save " through " table
# 1                              transpose/unzip function (inverse of zip)?
# 2                           detecting audio silence in wav files using c#
# 3                                     how to request a random row in sql?
# 4  mod_rewrite rule to redirect all requests except for one specific path
#
#                                                                                                                                                                                                       Body  \
# 0  <p>I'm having trouble in saving a m2m data, containing a 'through' class table.\nI want to save all selected members (selected in the form) in the through table.\nBut i don't know how to initialis...
# 1  <p>I have a list of 2-item tuples and I'd like to convert them to 2 lists where the first contains the first item in each tuple and the second list holds the second item.</p>\n\n<p><strong>For exa...
# 2  <p>I'm tasked with building a .NET client app to detect silence in a WAV files.</p>\n\n<p>Is this possible with the built-in Windows APIs? Or alternately, any good libraries out there to help with...
# 3                                                                                                        <p>How can I request a random row (or as close to truly random as is possible) in pure SQL?</p>\n
# 4  <p>I'm trying to redirect all requests to my domain to another domain using mod_rewrite in an Apache 2.2 VirtualHost declaration. There is one exception to this -- I'd like all requests  to the <c...
#
#                                 Tags  \
# 0               <django><forms><m2m>
# 1  <python><list><matrix><transpose>
# 2                  <c#><.net><audio>
# 3                      <sql><random>
# 4              <apache><mod-rewrite>
#
#                                                                                                                                                                                                       text  \
# 0  i'm having trouble in saving a m2m data, containing a 'through' class table.\ni want to save all selected members (selected in the form) in the through table.\nbut i don't know how to initialise t...
# 1  i have a list of 2-item tuples and i'd like to convert them to 2 lists where the first contains the first item in each tuple and the second list holds the second item.\nfor example:\noriginal = [(...
# 2         i'm tasked with building a .net client app to detect silence in a wav files.\nis this possible with the built-in windows apis? or alternately, any good libraries out there to help with this?\n
# 3                                                                                                               how can i request a random row (or as close to truly random as is possible) in pure sql?\n
# 4  i'm trying to redirect all requests to my domain to another domain using mod_rewrite in an apache 2.2 virtualhost declaration. there is one exception to this -- i'd like all requests  to the /audi...
#
#    nb_char  \
# 0     1442
# 1      350
# 2      190
# 3       89
# 4     1990
#
#                                                                                                                                                                                                     tokens  \
# 0  [i, m, having, trouble, in, saving, a, m2m, data, containing, a, through, class, table, i, want, to, save, all, selected, members, selected, in, the, form, in, the, through, table, but, i, don, t,...
# 1  [i, have, a, list, of, 2, item, tuples, and, i, d, like, to, convert, them, to, 2, lists, where, the, first, contains, the, first, item, in, each, tuple, and, the, second, list, holds, the, second...
# 2  [i, m, tasked, with, building, a, net, client, app, to, detect, silence, in, a, wav, files, is, this, possible, with, the, built, in, windows, apis, or, alternately, any, good, libraries, out, the...
# 3                                                                                                [how, can, i, request, a, random, row, or, as, close, to, truly, random, as, is, possible, in, pure, sql]
# 4  [i, m, trying, to, redirect, all, requests, to, my, domain, to, another, domain, using, mod, rewrite, in, an, apache, 2, 2, virtualhost, declaration, there, is, one, exception, to, this, i, d, lik...
#
#                                                                           tokens_title  \
# 0                                            [django, m2m, form, save, through, table]
# 1                                       [transpose, unzip, function, inverse, of, zip]
# 2                               [detecting, audio, silence, in, wav, files, using, c#]
# 3                                          [how, to, request, a, random, row, in, sql]
# 4  [mod, rewrite, rule, to, redirect, all, requests, except, for, one, specific, path]
#
#    nb_tokens  \
# 0        188
# 1         70
# 2         36
# 3         19
# 4        314
#
#                                                                                                                                                                                              tokens_unique  \
# 0  (through, foreignkey, unique, if, be, valid, default, know, containing, classname, want, name, trouble, m, data, how, new, code, 140, creator, is, right, model, don, instance, method, booleanfield...
# 1  (have, d, list, and, result, to, lists, c, convert, second, example, 2, for, original, 4, holds, want, builtin, #, there, item, them, that, tuples, contains, where, first, in, function, does, like...
# 2         (good, tasked, silence, to, windows, app, files, this, help, alternately, any, there, is, wav, built, detect, m, in, building, possible, libraries, or, apis, out, with, a, the, i, net, client)
# 3                                                                                                            (a, row, how, i, sql, in, to, close, can, truly, request, possible, is, or, random, pure, as)
# 4  (rewriteengine, path, if, anyone, error, customlog, be, expect, perfect, work, still, sense, rewrite, contains, what, m, wrong, slash, s, requests, does, without, newdomain, 301, mod, net, is, rig...
#
#    nb_tokens_unique  \
# 0                82
# 1                42
# 2                30
# 3                17
# 4               148
#
#                                                                                                                                                                                                 tokens_WSW  \
# 0  [trouble, saving, m2m, data, containing, class, table, want, save, selected, members, selected, form, table, know, initialise, table, view, code, class, classroom, models, model, user, models, for...
# 1            [list, item, tuples, like, convert, lists, first, contains, first, item, tuple, second, list, holds, second, item, example, original, b, c, #, want, become, result, b, c, builtin, function]
# 2                                                                    [tasked, building, net, client, app, detect, silence, wav, files, possible, built, windows, apis, alternately, good, libraries, help]
# 3                                                                                                                                        [request, random, row, close, truly, random, possible, pure, sql]
# 4  [trying, redirect, requests, domain, another, domain, using, mod, rewrite, apache, virtualhost, declaration, one, exception, like, requests, audio, path, redirected, written, rewritecond, rewriter...
#
#                                                         tokens_title_WSW  \
# 0                                       [django, m2m, form, save, table]
# 1                             [transpose, unzip, function, inverse, zip]
# 2                     [detecting, audio, silence, wav, files, using, c#]
# 3                                            [request, random, row, sql]
# 4  [mod, rewrite, rule, redirect, requests, except, one, specific, path]
#
#    nb_tokens_WSW
# 0            141
# 1             28
# 2             17
# 3              9
# 4            191

# %% [markdown]
# ## Lemmatization

# %% [raw]
# from spacy.tokenizer import Tokenizer
# suffix_re = re.compile(r'''[])"']$''')
# def custom_tokenizer(nlp):
#     return Tokenizer(nlp.vocab, suffix_search=suffix_re.search)
#
# test = ListToString(tokenWithoutSW[0])
# print(test)
# nlp.tokenizer = custom_tokenizer(nlp)
# doc = nlp(test)
# tok_exp = nlp.tokenizer.explain(test)
# for t in tok_exp:
#     print(t[1], "\t", t[0])
# liste = [token for token in doc]
# print(liste)

# %%
#python -m spacy download en_core_web_sm

# %%
nlp = spacy.load("en_core_web_sm")

# %%
SPECIAL_TAGS = '@.' # remplace les caractères spéciaux
def ListToString(liste):
    listSaveWords = []
    liste2 = liste.copy()
    for word in liste:
        if word.find('+')!=-1 or word.find('#')!=-1:
            saveWord = word
            liste2[liste.index(saveWord)] = SPECIAL_TAGS # special tags
            listSaveWords.append(saveWord)
            
    phrase = ' '.join(liste2)
    return (phrase,listSaveWords)

# %%
#tokenWithoutSW[0:3]

# %%
tokenWithoutSWCopy = tokenWithoutSW.copy()
TokenLemma = []
for tokenList in tokenWithoutSWCopy:
        #display(data.head())
        text, listSaveWords = ListToString(tokenList)
        #display(data.head())
        #print(text)
        #print(listSaveWords)
        doc = nlp(text)
        liste = []
        k=0
        for token in doc:
            #print(token)
            if str(token.lemma_) == SPECIAL_TAGS:
                token = listSaveWords[k]
                k=+1
                liste.append(token)
            else:
                liste.append(token.lemma_)
        TokenLemma.append(liste)

#final_string = ' '.join(map(str,empty_list))

# %%
display(TokenLemma[2])
display(tokenWithoutSW[2])
display(TokenLemma[0])
display(tokenWithoutSW[0])
# Out:
# ['task',
#  'build',
#  'net',
#  'client',
#  'app',
#  'detect',
#  'silence',
#  'wav',
#  'file',
#  'possible',
#  'build',
#  'window',
#  'apis',
#  'alternately',
#  'good',
#  'library',
#  'help']
# ['tasked',
#  'building',
#  'net',
#  'client',
#  'app',
#  'detect',
#  'silence',
#  'wav',
#  'files',
#  'possible',
#  'built',
#  'windows',
#  'apis',
#  'alternately',
#  'good',
#  'libraries',
#  'help']
# ['trouble',
#  'save',
#  'm2',
#  'm',
#  'datum',
#  'contain',
#  'class',
#  'table',
#  'want',
#  'save',
#  'select',
#  'member',
#  'select',
#  'form',
#  'table',
#  'know',
#  'initialise',
#  'table',
#  'view',
#  'code',
#  'class',
#  'classroom',
#  'model',
#  'model',
#  'user',
#  'model',
#  'foreignkey',
#  'user',
#  'relate',
#  'name',
#  'classroom',
#  'creator',
#  'classname',
#  'model',
#  'charfield',
#  'max',
#  'length',
#  'unique',
#  'true',
#  'date',
#  'model',
#  'datetimefield',
#  'auto',
#  'true',
#  'open',
#  'class',
#  'model',
#  'booleanfield',
#  'default',
#  'true',
#  'member',
#  'model',
#  'manytomanyfield',
#  'user',
#  'relate',
#  'name',
#  'list',
#  'invite',
#  'member',
#  'membership',
#  'class',
#  'membership',
#  'model',
#  'model',
#  'accept',
#  'model',
#  'booleanfield',
#  'user',
#  'date',
#  'model',
#  'datetimefield',
#  'auto',
#  'true',
#  'classroom',
#  'model',
#  'foreignkey',
#  'classroom',
#  'relate',
#  'name',
#  'classroom',
#  'membership',
#  'member',
#  'model',
#  'foreignkey',
#  'user',
#  'relate',
#  'name',
#  'user',
#  'membership',
#  'view',
#  'def',
#  'save',
#  'classroom',
#  'request',
#  'classroom',
#  'instance',
#  'classroom',
#  'request',
#  'method',
#  'post',
#  'form',
#  'classroomform',
#  'request',
#  'post',
#  'request',
#  'file',
#  'user',
#  'request',
#  'user',
#  'form',
#  'valid',
#  'new',
#  'obj',
#  'form',
#  'save',
#  'commit',
#  'false',
#  'new',
#  'obj',
#  'user',
#  'request',
#  'user',
#  'new',
#  'obj',
#  'save',
#  'membership',
#  'membership',
#  'member',
#  'select',
#  'item',
#  'form',
#  'classroom',
#  'new',
#  'obj',
#  'membership',
#  'save',
#  'initialise',
#  'membership',
#  'membership',
#  'table',
#  'populate',
#  'right']
# ['trouble',
#  'saving',
#  'm2m',
#  'data',
#  'containing',
#  'class',
#  'table',
#  'want',
#  'save',
#  'selected',
#  'members',
#  'selected',
#  'form',
#  'table',
#  'know',
#  'initialise',
#  'table',
#  'view',
#  'code',
#  'class',
#  'classroom',
#  'models',
#  'model',
#  'user',
#  'models',
#  'foreignkey',
#  'user',
#  'related',
#  'name',
#  'classroom',
#  'creator',
#  'classname',
#  'models',
#  'charfield',
#  'max',
#  'length',
#  'unique',
#  'true',
#  'date',
#  'models',
#  'datetimefield',
#  'auto',
#  'true',
#  'open',
#  'class',
#  'models',
#  'booleanfield',
#  'default',
#  'true',
#  'members',
#  'models',
#  'manytomanyfield',
#  'user',
#  'related',
#  'name',
#  'list',
#  'invited',
#  'members',
#  'membership',
#  'class',
#  'membership',
#  'models',
#  'model',
#  'accept',
#  'models',
#  'booleanfield',
#  'user',
#  'date',
#  'models',
#  'datetimefield',
#  'auto',
#  'true',
#  'classroom',
#  'models',
#  'foreignkey',
#  'classroom',
#  'related',
#  'name',
#  'classroom',
#  'membership',
#  'member',
#  'models',
#  'foreignkey',
#  'user',
#  'related',
#  'name',
#  'user',
#  'membership',
#  'view',
#  'def',
#  'save',
#  'classroom',
#  'request',
#  'classroom',
#  'instance',
#  'classroom',
#  'request',
#  'method',
#  'post',
#  'form',
#  'classroomform',
#  'request',
#  'post',
#  'request',
#  'files',
#  'user',
#  'request',
#  'user',
#  'form',
#  'valid',
#  'new',
#  'obj',
#  'form',
#  'save',
#  'commit',
#  'false',
#  'new',
#  'obj',
#  'user',
#  'request',
#  'user',
#  'new',
#  'obj',
#  'save',
#  'membership',
#  'membership',
#  'member',
#  'selected',
#  'items',
#  'form',
#  'classroom',
#  'new',
#  'obj',
#  'membership',
#  'save',
#  'initialise',
#  'membership',
#  'membership',
#  'table',
#  'populated',
#  'right']

# %%
data['tokens_lemma'] = TokenLemma
data['len_tokens_lemma'] = data['tokens_lemma'].apply(lambda x: len(x))

# %%
data.head()
# Out:
#                                                                     Title  \
# 0                                  django m2m form save " through " table
# 1                              transpose/unzip function (inverse of zip)?
# 2                           detecting audio silence in wav files using c#
# 3                                     how to request a random row in sql?
# 4  mod_rewrite rule to redirect all requests except for one specific path
#
#                                                                                                                                                                                                       Body  \
# 0  <p>I'm having trouble in saving a m2m data, containing a 'through' class table.\nI want to save all selected members (selected in the form) in the through table.\nBut i don't know how to initialis...
# 1  <p>I have a list of 2-item tuples and I'd like to convert them to 2 lists where the first contains the first item in each tuple and the second list holds the second item.</p>\n\n<p><strong>For exa...
# 2  <p>I'm tasked with building a .NET client app to detect silence in a WAV files.</p>\n\n<p>Is this possible with the built-in Windows APIs? Or alternately, any good libraries out there to help with...
# 3                                                                                                        <p>How can I request a random row (or as close to truly random as is possible) in pure SQL?</p>\n
# 4  <p>I'm trying to redirect all requests to my domain to another domain using mod_rewrite in an Apache 2.2 VirtualHost declaration. There is one exception to this -- I'd like all requests  to the <c...
#
#                                 Tags  \
# 0               <django><forms><m2m>
# 1  <python><list><matrix><transpose>
# 2                  <c#><.net><audio>
# 3                      <sql><random>
# 4              <apache><mod-rewrite>
#
#                                                                                                                                                                                                       text  \
# 0  i'm having trouble in saving a m2m data, containing a 'through' class table.\ni want to save all selected members (selected in the form) in the through table.\nbut i don't know how to initialise t...
# 1  i have a list of 2-item tuples and i'd like to convert them to 2 lists where the first contains the first item in each tuple and the second list holds the second item.\nfor example:\noriginal = [(...
# 2         i'm tasked with building a .net client app to detect silence in a wav files.\nis this possible with the built-in windows apis? or alternately, any good libraries out there to help with this?\n
# 3                                                                                                               how can i request a random row (or as close to truly random as is possible) in pure sql?\n
# 4  i'm trying to redirect all requests to my domain to another domain using mod_rewrite in an apache 2.2 virtualhost declaration. there is one exception to this -- i'd like all requests  to the /audi...
#
#    nb_char  \
# 0     1442
# 1      350
# 2      190
# 3       89
# 4     1990
#
#                                                                                                                                                                                                     tokens  \
# 0  [i, m, having, trouble, in, saving, a, m2m, data, containing, a, through, class, table, i, want, to, save, all, selected, members, selected, in, the, form, in, the, through, table, but, i, don, t,...
# 1  [i, have, a, list, of, 2, item, tuples, and, i, d, like, to, convert, them, to, 2, lists, where, the, first, contains, the, first, item, in, each, tuple, and, the, second, list, holds, the, second...
# 2  [i, m, tasked, with, building, a, net, client, app, to, detect, silence, in, a, wav, files, is, this, possible, with, the, built, in, windows, apis, or, alternately, any, good, libraries, out, the...
# 3                                                                                                [how, can, i, request, a, random, row, or, as, close, to, truly, random, as, is, possible, in, pure, sql]
# 4  [i, m, trying, to, redirect, all, requests, to, my, domain, to, another, domain, using, mod, rewrite, in, an, apache, 2, 2, virtualhost, declaration, there, is, one, exception, to, this, i, d, lik...
#
#                                                                           tokens_title  \
# 0                                            [django, m2m, form, save, through, table]
# 1                                       [transpose, unzip, function, inverse, of, zip]
# 2                               [detecting, audio, silence, in, wav, files, using, c#]
# 3                                          [how, to, request, a, random, row, in, sql]
# 4  [mod, rewrite, rule, to, redirect, all, requests, except, for, one, specific, path]
#
#    nb_tokens  \
# 0        188
# 1         70
# 2         36
# 3         19
# 4        314
#
#                                                                                                                                                                                              tokens_unique  \
# 0  (through, foreignkey, unique, if, be, valid, default, know, containing, classname, want, name, trouble, m, data, how, new, code, 140, creator, is, right, model, don, instance, method, booleanfield...
# 1  (have, d, list, and, result, to, lists, c, convert, second, example, 2, for, original, 4, holds, want, builtin, #, there, item, them, that, tuples, contains, where, first, in, function, does, like...
# 2         (good, tasked, silence, to, windows, app, files, this, help, alternately, any, there, is, wav, built, detect, m, in, building, possible, libraries, or, apis, out, with, a, the, i, net, client)
# 3                                                                                                            (a, row, how, i, sql, in, to, close, can, truly, request, possible, is, or, random, pure, as)
# 4  (rewriteengine, path, if, anyone, error, customlog, be, expect, perfect, work, still, sense, rewrite, contains, what, m, wrong, slash, s, requests, does, without, newdomain, 301, mod, net, is, rig...
#
#    nb_tokens_unique  \
# 0                82
# 1                42
# 2                30
# 3                17
# 4               148
#
#                                                                                                                                                                                                 tokens_WSW  \
# 0  [trouble, saving, m2m, data, containing, class, table, want, save, selected, members, selected, form, table, know, initialise, table, view, code, class, classroom, models, model, user, models, for...
# 1            [list, item, tuples, like, convert, lists, first, contains, first, item, tuple, second, list, holds, second, item, example, original, b, c, #, want, become, result, b, c, builtin, function]
# 2                                                                    [tasked, building, net, client, app, detect, silence, wav, files, possible, built, windows, apis, alternately, good, libraries, help]
# 3                                                                                                                                        [request, random, row, close, truly, random, possible, pure, sql]
# 4  [trying, redirect, requests, domain, another, domain, using, mod, rewrite, apache, virtualhost, declaration, one, exception, like, requests, audio, path, redirected, written, rewritecond, rewriter...
#
#                                                         tokens_title_WSW  \
# 0                                       [django, m2m, form, save, table]
# 1                             [transpose, unzip, function, inverse, zip]
# 2                     [detecting, audio, silence, wav, files, using, c#]
# 3                                            [request, random, row, sql]
# 4  [mod, rewrite, rule, redirect, requests, except, one, specific, path]
#
#    nb_tokens_WSW  \
# 0            141
# 1             28
# 2             17
# 3              9
# 4            191
#
#                                                                                                                                                                                               tokens_lemma  \
# 0  [trouble, save, m2, m, datum, contain, class, table, want, save, select, member, select, form, table, know, initialise, table, view, code, class, classroom, model, model, user, model, foreignkey, ...
# 1                [list, item, tuple, like, convert, list, first, contain, first, item, tuple, second, list, hold, second, item, example, original, b, c, #, want, become, result, b, c, builtin, function]
# 2                                                                             [task, build, net, client, app, detect, silence, wav, file, possible, build, window, apis, alternately, good, library, help]
# 3                                                                                                                                        [request, random, row, close, truly, random, possible, pure, sql]
# 4  [try, redirect, request, domain, another, domain, use, mod, rewrite, apache, virtualhost, declaration, one, exception, like, request, audio, path, redirect, write, rewritecond, rewriterule, quite,...
#
#    len_tokens_lemma
# 0               142
# 1                28
# 2                17
# 3                 9
# 4               191

# %% [markdown]
# ## Tags to list

# %%
stringTags = data['Tags'].apply(lambda x : re.sub(r'^[<>]','',x.strip()))
stringTags = stringTags.apply(lambda x : re.sub(r'[<>]$','',x.strip()))
stringTags.head()
# Out:
# 0                 django><forms><m2m
# 1    python><list><matrix><transpose
# 2                    c#><.net><audio
# 3                        sql><random
# 4                apache><mod-rewrite
# Name: Tags, dtype: object

# %%
data['Tags_list'] = stringTags.apply(lambda x : re.split(r'><',x))
data['Tags_list'] = data['Tags_list'].apply(lambda x : list(set(x))) # ! if the same tag is used multiple times

# %%
data['len _Tags_list'] = data['Tags_list'].apply(lambda x : len(x))

# %%
data.head()
# Out:
#                                                                     Title  \
# 0                                  django m2m form save " through " table
# 1                              transpose/unzip function (inverse of zip)?
# 2                           detecting audio silence in wav files using c#
# 3                                     how to request a random row in sql?
# 4  mod_rewrite rule to redirect all requests except for one specific path
#
#                                                                                                                                                                                                       Body  \
# 0  <p>I'm having trouble in saving a m2m data, containing a 'through' class table.\nI want to save all selected members (selected in the form) in the through table.\nBut i don't know how to initialis...
# 1  <p>I have a list of 2-item tuples and I'd like to convert them to 2 lists where the first contains the first item in each tuple and the second list holds the second item.</p>\n\n<p><strong>For exa...
# 2  <p>I'm tasked with building a .NET client app to detect silence in a WAV files.</p>\n\n<p>Is this possible with the built-in Windows APIs? Or alternately, any good libraries out there to help with...
# 3                                                                                                        <p>How can I request a random row (or as close to truly random as is possible) in pure SQL?</p>\n
# 4  <p>I'm trying to redirect all requests to my domain to another domain using mod_rewrite in an Apache 2.2 VirtualHost declaration. There is one exception to this -- I'd like all requests  to the <c...
#
#                                 Tags  \
# 0               <django><forms><m2m>
# 1  <python><list><matrix><transpose>
# 2                  <c#><.net><audio>
# 3                      <sql><random>
# 4              <apache><mod-rewrite>
#
#                                                                                                                                                                                                       text  \
# 0  i'm having trouble in saving a m2m data, containing a 'through' class table.\ni want to save all selected members (selected in the form) in the through table.\nbut i don't know how to initialise t...
# 1  i have a list of 2-item tuples and i'd like to convert them to 2 lists where the first contains the first item in each tuple and the second list holds the second item.\nfor example:\noriginal = [(...
# 2         i'm tasked with building a .net client app to detect silence in a wav files.\nis this possible with the built-in windows apis? or alternately, any good libraries out there to help with this?\n
# 3                                                                                                               how can i request a random row (or as close to truly random as is possible) in pure sql?\n
# 4  i'm trying to redirect all requests to my domain to another domain using mod_rewrite in an apache 2.2 virtualhost declaration. there is one exception to this -- i'd like all requests  to the /audi...
#
#    nb_char  \
# 0     1442
# 1      350
# 2      190
# 3       89
# 4     1990
#
#                                                                                                                                                                                                     tokens  \
# 0  [i, m, having, trouble, in, saving, a, m2m, data, containing, a, through, class, table, i, want, to, save, all, selected, members, selected, in, the, form, in, the, through, table, but, i, don, t,...
# 1  [i, have, a, list, of, 2, item, tuples, and, i, d, like, to, convert, them, to, 2, lists, where, the, first, contains, the, first, item, in, each, tuple, and, the, second, list, holds, the, second...
# 2  [i, m, tasked, with, building, a, net, client, app, to, detect, silence, in, a, wav, files, is, this, possible, with, the, built, in, windows, apis, or, alternately, any, good, libraries, out, the...
# 3                                                                                                [how, can, i, request, a, random, row, or, as, close, to, truly, random, as, is, possible, in, pure, sql]
# 4  [i, m, trying, to, redirect, all, requests, to, my, domain, to, another, domain, using, mod, rewrite, in, an, apache, 2, 2, virtualhost, declaration, there, is, one, exception, to, this, i, d, lik...
#
#                                                                           tokens_title  \
# 0                                            [django, m2m, form, save, through, table]
# 1                                       [transpose, unzip, function, inverse, of, zip]
# 2                               [detecting, audio, silence, in, wav, files, using, c#]
# 3                                          [how, to, request, a, random, row, in, sql]
# 4  [mod, rewrite, rule, to, redirect, all, requests, except, for, one, specific, path]
#
#    nb_tokens  \
# 0        188
# 1         70
# 2         36
# 3         19
# 4        314
#
#                                                                                                                                                                                              tokens_unique  \
# 0  (through, foreignkey, unique, if, be, valid, default, know, containing, classname, want, name, trouble, m, data, how, new, code, 140, creator, is, right, model, don, instance, method, booleanfield...
# 1  (have, d, list, and, result, to, lists, c, convert, second, example, 2, for, original, 4, holds, want, builtin, #, there, item, them, that, tuples, contains, where, first, in, function, does, like...
# 2         (good, tasked, silence, to, windows, app, files, this, help, alternately, any, there, is, wav, built, detect, m, in, building, possible, libraries, or, apis, out, with, a, the, i, net, client)
# 3                                                                                                            (a, row, how, i, sql, in, to, close, can, truly, request, possible, is, or, random, pure, as)
# 4  (rewriteengine, path, if, anyone, error, customlog, be, expect, perfect, work, still, sense, rewrite, contains, what, m, wrong, slash, s, requests, does, without, newdomain, 301, mod, net, is, rig...
#
#    nb_tokens_unique  \
# 0                82
# 1                42
# 2                30
# 3                17
# 4               148
#
#                                                                                                                                                                                                 tokens_WSW  \
# 0  [trouble, saving, m2m, data, containing, class, table, want, save, selected, members, selected, form, table, know, initialise, table, view, code, class, classroom, models, model, user, models, for...
# 1            [list, item, tuples, like, convert, lists, first, contains, first, item, tuple, second, list, holds, second, item, example, original, b, c, #, want, become, result, b, c, builtin, function]
# 2                                                                    [tasked, building, net, client, app, detect, silence, wav, files, possible, built, windows, apis, alternately, good, libraries, help]
# 3                                                                                                                                        [request, random, row, close, truly, random, possible, pure, sql]
# 4  [trying, redirect, requests, domain, another, domain, using, mod, rewrite, apache, virtualhost, declaration, one, exception, like, requests, audio, path, redirected, written, rewritecond, rewriter...
#
#                                                         tokens_title_WSW  \
# 0                                       [django, m2m, form, save, table]
# 1                             [transpose, unzip, function, inverse, zip]
# 2                     [detecting, audio, silence, wav, files, using, c#]
# 3                                            [request, random, row, sql]
# 4  [mod, rewrite, rule, redirect, requests, except, one, specific, path]
#
#    nb_tokens_WSW  \
# 0            141
# 1             28
# 2             17
# 3              9
# 4            191
#
#                                                                                                                                                                                               tokens_lemma  \
# 0  [trouble, save, m2, m, datum, contain, class, table, want, save, select, member, select, form, table, know, initialise, table, view, code, class, classroom, model, model, user, model, foreignkey, ...
# 1                [list, item, tuple, like, convert, list, first, contain, first, item, tuple, second, list, hold, second, item, example, original, b, c, #, want, become, result, b, c, builtin, function]
# 2                                                                             [task, build, net, client, app, detect, silence, wav, file, possible, build, window, apis, alternately, good, library, help]
# 3                                                                                                                                        [request, random, row, close, truly, random, possible, pure, sql]
# 4  [try, redirect, request, domain, another, domain, use, mod, rewrite, apache, virtualhost, declaration, one, exception, like, request, audio, path, redirect, write, rewritecond, rewriterule, quite,...
#
#    len_tokens_lemma                          Tags_list  len _Tags_list
# 0               142               [django, forms, m2m]               3
# 1                28  [list, transpose, matrix, python]               4
# 2                17                  [c#, audio, .net]               3
# 3                 9                      [random, sql]               2
# 4               191              [apache, mod-rewrite]               2

# %%
plt.figure(figsize=(12,12))
plt.scatter(data['len _Tags_list'], data['nb_tokens_unique'])
plt.xlabel('number of tags')
plt.ylabel('number of unique tokens in the text')
plt.title('number of tags versus number of unique tokens in texts')
plt.show()

# %% [markdown]
# ### Tags Frequency

# %%
tagsDic = wordFrequency(data['Tags_list'])
name = [tagsName for tagsName in tagsDic.keys()]
count = [ tagsDic[tagsName] for tagsName in tagsDic.keys()]
tagsFreq = pd.DataFrame({'name_tags':name,'count_tags':count})
tagsFreq = tagsFreq.sort_values(by=['count_tags'],ascending=False)
nbTotalTags = tagsFreq['count_tags'].sum()
tagsFreq['occurence(%)'] = tagsFreq['count_tags']/nbTotalTags*100
nbPosts = len(data['Tags_list'])
tagsFreq['occurence_in_posts(%)'] = tagsFreq['count_tags']/nbPosts*100

# %%
len(data['len _Tags_list']) # number of posts
# Out:
# 48023

# %%
data['len _Tags_list'].value_counts()
# Out:
# 3    14684
# 2    11675
# 4    10726
# 5     6998
# 1     3940
# Name: len _Tags_list, dtype: int64

# %%
nbTotalTags # total number of tags EX: [[python,list,form], [c,C++; list],[dataframe,numpy]]
# Out:
# 149236

# %%
len(tagsFreq) # nb of unique tags EX: [python, C,C++,numpy]
# Out:
# 11425

# %%
(data['Tags_list'].apply(lambda x: list(set(x))) == data['Tags_list']).value_counts()
# Out:
# True     42180
# False     5843
# Name: Tags_list, dtype: int64

# %%
data['Tags_list'].loc[0]
# Out:
# ['django', 'forms', 'm2m']

# %%
list(['m2m', 'forms', 'django'])
# Out:
# ['m2m', 'forms', 'django']

# %%
data['len _Tags_list'].describe() # statistic on number of tags per posts
# Out:
# count    48023.000000
# mean         3.107594
# std          1.168751
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: len _Tags_list, dtype: float64

# %%
tagsFreq.head(20)
# Out:
#        name_tags  count_tags  occurence(%)  occurence_in_posts(%)
# 6         python        4583      3.070975               9.543344
# 7             c#        4211      2.821705               8.768715
# 42          java        4091      2.741296               8.518835
# 45    javascript        3940      2.640114               8.204402
# 113          c++        2488      1.667158               5.180851
# 60       android        2165      1.450722               4.508256
# 9           .net        2122      1.421909               4.418716
# 16           php        1654      1.108312               3.444183
# 272         html        1649      1.104961               3.433771
# 212          ios        1541      1.032593               3.208879
# 171       jquery        1493      1.000429               3.108927
# 156            c        1280      0.857702               2.665390
# 214          css        1222      0.818837               2.544614
# 11           sql        1113      0.745799               2.317639
# 15        iphone        1084      0.726366               2.257252
# 132          git        1063      0.712295               2.213523
# 101  objective-c         964      0.645957               2.007371
# 22         mysql         889      0.595701               1.851196
# 223        linux         886      0.593691               1.844949
# 33       asp.net         812      0.544105               1.690856

# %%
plt.figure(figsize=(30,11))
plt.xticks(rotation=90)
plt.bar(tagsFreq['name_tags'][tagsFreq['count_tags']>400],tagsFreq['occurence(%)'][tagsFreq['count_tags']>400])
plt.show()

# %%
plt.figure(figsize=(30,11))
plt.xticks(rotation=90)
plt.bar(tagsFreq['name_tags'][tagsFreq['count_tags']>400],tagsFreq['occurence_in_posts(%)'][tagsFreq['count_tags']>400])
plt.show()

# %% [markdown]
# Most Frequent Tags in corpus.

# %%
tagsFreq=tagsFreq.reset_index(drop=True)

# %%
tagsFreq['occurence_cumulative'] = np.cumsum(tagsFreq['occurence(%)'])

# %%
plt.figure(figsize=(30,11))
plt.xticks(rotation=90)
plt.bar(tagsFreq['name_tags'][tagsFreq['occurence_cumulative']<90],tagsFreq['occurence_cumulative'][tagsFreq['occurence_cumulative']<90])
plt.show()

# %%
plt.figure(figsize=(30,11))
plt.xticks(rotation=90)
plt.bar(tagsFreq['name_tags'][tagsFreq['occurence_cumulative']<50],tagsFreq['occurence_cumulative'][tagsFreq['occurence_cumulative']<50])
plt.show()

# %% [markdown]
# the 144 most used tags in the corpus.

# %%
tagsFreq[tagsFreq['name_tags']=='enums']
# Out:
#     name_tags  count_tags  occurence(%)  occurence_in_posts(%)  \
# 143     enums         141      0.094481               0.293609
#
#      occurence_cumulative
# 143             49.971187

# %%
0.094481*50000/100
# Out:
# 47.240500000000004

# %% [markdown]
# ## keep only the most used tags in a new column

# %%
nameTags =tagsFreq['name_tags'][tagsFreq['occurence_cumulative']<50]
data['filtered_tags'] = data['Tags_list'].apply(lambda x : [tag for tag in x if tag in nameTags.values])
checkNewCol = wordFrequency(data['filtered_tags'])
print(len(checkNewCol.keys()))
# Out:
# 144

# %% [markdown]
# we keep 144 Tags in the new column 'filtered_tags'

# %% [markdown]
# ## occurence matrix

# %%
len(tagsFreq['name_tags'][tagsFreq['occurence_cumulative']<50]) # number of tags which represent 50% of the distribution in total number of tags
# Out:
# 144

# %%
def occurenceMatrix(data, wordColumn):
    '''  search occurence of wordColumn(list) into data(pandas series) '''
    lenColumns = len(wordColumn)
    matrix = np.ndarray(shape=(lenColumns,lenColumns), dtype=np.float64())
    for indx, tag1 in enumerate(wordColumn):
        for indy , tag2 in enumerate(wordColumn):
            if tag1 != tag2:
                sumTags1=0
                sumTags2=0
                sumBinome = 0
                for j in data:
                    if tag1 in j:
                        sumTags1+=1
                        if tag2 in j:
                            sumBinome+=1
                    if tag2 in j:
                        sumTags2+=1
            else:
                sumTags1 = sumTags2 = 1
                sumBinome = 0
                
            matrix[indx,indy]=sumBinome/(sumTags1*sumTags2)
    #print(matrix)
    return matrix

# %%
res=occurenceMatrix(data['Tags_list'],tagsFreq['name_tags'][tagsFreq['occurence_cumulative']<50])

# %%
nameTags =tagsFreq['name_tags'][tagsFreq['occurence_cumulative']<50]

# %%
res
# Out:
# array([[0.00000000e+00, 5.18161214e-07, 2.02676903e-06, ...,
#         0.00000000e+00, 3.50947329e-05, 1.08325093e-05],
#        [5.18161214e-07, 0.00000000e+00, 3.59895958e-06, ...,
#         6.97473982e-05, 3.65343514e-05, 7.07367230e-05],
#        [2.02676903e-06, 3.59895958e-06, 0.00000000e+00, ...,
#         1.70936372e-06, 4.78621843e-05, 6.93444007e-05],
#        ...,
#        [0.00000000e+00, 6.97473982e-05, 1.70936372e-06, ...,
#         0.00000000e+00, 0.00000000e+00, 4.95957943e-05],
#        [3.50947329e-05, 3.65343514e-05, 4.78621843e-05, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.08325093e-05, 7.07367230e-05, 6.93444007e-05, ...,
#         4.95957943e-05, 0.00000000e+00, 0.00000000e+00]])

# %%
fig, ax = plt.subplots(figsize=(30,30))
im = ax.imshow(res)

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(nameTags)), labels=nameTags)
ax.set_yticks(np.arange(len(nameTags)), labels=nameTags)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
#for i in range(len(nameTags)):
#    for j in range(len(nameTags)):
#        text = ax.text(j, i, res[i, j],
#                       ha="center", va="center", color="w")

ax.set_title("Tags occurence")
#fig.tight_layout()
plt.show()

# %%
res[12,7]
# Out:
# 5.4423438096802475e-06

# %%
res[7,12]
# Out:
# 5.4423438096802475e-06

# %%
np.max(res)
# Out:
# 0.0018244731047499213

# %% [markdown]
# ## Conditional Probability

# %%
def conditionalMatrix(data, wordColumn):
    '''  search occurence of wordColumn(list) into data(pandas series) '''
    lenColumns = len(wordColumn)
    matrix = np.ndarray(shape=(lenColumns,lenColumns), dtype=np.float64())
    for indx, tag1 in enumerate(wordColumn):
        for indy , tag2 in enumerate(wordColumn):
                sumTags1=0
                sumBinome = 0
                for j in data:
                    if tag1 in j:
                        sumTags1+=1
                        if tag2 in j:
                            sumBinome+=1
                matrix[indx,indy]=sumBinome/(sumTags1)
    #print(matrix)
    return matrix

# %%
res=conditionalMatrix(data['Tags_list'],tagsFreq['name_tags'][tagsFreq['occurence_cumulative']<50])

# %%
fig, ax = plt.subplots(figsize=(25,25))
im = plt.imshow(res)

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(nameTags)), labels=nameTags)
ax.set_yticks(np.arange(len(nameTags)), labels=nameTags)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
#for i in range(len(nameTags)):
#    for j in range(len(nameTags)):
#        text = ax.text(j, i, res[i, j],
#                       ha="center", va="center", color="w")
cax = plt.axes([0.95, 0.15, 0.075, 0.7])
plt.colorbar(cax=cax)


ax.set_title("Tags occurence")
#fig.tight_layout()
plt.show()

# %%
maskedRes = np.ma.masked_less_equal(res, 0.5) #mask value below 0.5
fig, ax = plt.subplots(figsize=(25,25))
im = plt.imshow(maskedRes)

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(nameTags)), labels=nameTags)
ax.set_yticks(np.arange(len(nameTags)), labels=nameTags)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
#for i in range(len(nameTags)):
#    for j in range(len(nameTags)):
#        text = ax.text(j, i, res[i, j],
#                       ha="center", va="center", color="w")
cax = plt.axes([0.95, 0.15, 0.075, 0.7])
plt.colorbar(cax=cax)

ax.grid(color='black', linestyle='-', linewidth=1)

ax.set_title("Tags occurence")
#fig.tight_layout()
plt.show()

# %% [markdown]
# ## tag list reduced

# %%
listePeakWord = []
tagListReduced  = []
dicoWord = {}
indWord = 0
# regroupement des tags en fonction de leurs probabilités
for ind, tag in enumerate(nameTags):

    if len(np.where(maskedRes[ind,:].mask ==False)[0])==1: 
            dicoWord.update({tag:indWord})
            listePeakWord.append(tag)
            tagListReduced.append([tag])
            indWord+=1
    else:
        indSubWords = np.where(maskedRes[ind,:].mask == False)[0]
        nameSubWord = [ nameTags.iloc[i] for i in indSubWords]
        for name in nameSubWord:
            if name != tag :
                position=dicoWord[name]
                tagListReduced[position].append(tag)
                listePeakWord.append(tag)
                dicoWord.update({tag:position})

tagListReduced = [ list(set(i)) for i in tagListReduced]
print(f'len tagsList :{len(nameTags)}')
print(f'len tagsListReduced :{len(tagListReduced)}')
print(f'{tagListReduced}\n')
##suppression des doublons: regroupement des catégories qui contiennent le meme mots
liste =[]
nonUniqueWords=[]
# count nb of non unique words
for j in tagListReduced: liste+=j
for name in nameTags:
    if liste.count(name) !=1:
        print(f'word: {name}\tnb count: {liste.count(name)}')
        nonUniqueWords.append(name)

print(f'{"-"*20}\n')       
        
        
dicoValue={}
for word in nonUniqueWords:
    value=[]
    for ind, Tags in enumerate(tagListReduced):
        if Tags.count(word)!=0:
            value.append(Tags)
    dicoValue[word]=value
                        
print(dicoValue)
#### Solution temporaire
if len(dicoValue.keys()) == 2:
    key1 , key2 = dicoValue.keys()
    if dicoValue[key1]  == dicoValue[key2]:
        liste = []
        for val in dicoValue[key1]:
            liste += val
            tagListReduced.remove(val)
        liste = list(set(liste))
        tagListReduced.append(liste)
    else:
        raise Exception("non unique words have not the same indices configuration, can not merge Tags")
else:
    raise Exception("nb of non unique word is not equal to 2")
    
print(f'len tagsListReduced :{len(tagListReduced)}')
print(f'{tagListReduced}\n')
# Out:
# len tagsList :144
# len tagsListReduced :110
# [['numpy', 'python-3.x', 'list', 'pandas', 'dictionary', 'dataframe', 'django', 'matplotlib', 'python'], ['c#', 'winforms', 'generics', 'reflection', 'linq', '.net'], ['java', 'hibernate', 'spring', 'collections'], ['javascript', 'jquery', 'dom', 'ajax'], ['c++', 'c++11', 'templates'], ['android-studio', 'android'], ['php', 'laravel'], ['html'], ['ios', 'swift', 'uitableview', 'xcode', 'ios7'], ['pointers', 'c'], ['css'], ['sql-server-2005', 'sql', 'tsql'], ['iphone', 'cocoa-touch'], ['github', 'git'], ['cocoa', 'objective-c'], ['mysql'], ['linux'], ['asp.net'], ['batch-file', 'windows'], ['sql-server', 'sql-server-2005', 'tsql'], ['string'], ['algorithm'], ['ruby'], ['ruby-on-rails'], ['bash'], ['asp.net-mvc'], ['performance'], ['node.js'], ['arrays'], ['database'], ['r'], ['multithreading'], ['regex'], ['wpf'], ['json'], ['visual-studio'], ['macos'], ['reactjs'], ['shell'], ['angularjs'], ['unit-testing'], ['language-agnostic'], ['eclipse'], ['oop'], ['vim'], ['xml'], ['angular'], ['svn'], ['debugging'], ['postgresql'], ['http'], ['security'], ['unix'], ['version-control'], ['design-patterns'], ['image'], ['datetime'], ['file'], ['rest'], ['docker'], ['command-line'], ['math'], ['exception'], ['typescript'], ['function'], ['twitter-bootstrap'], ['scala'], ['authentication'], ['date'], ['optimization'], ['sorting'], ['oracle'], ['logging'], ['class'], ['user-interface'], ['mongodb'], ['go'], ['data-structures'], ['gcc'], ['firebase'], ['parsing'], ['web-services'], ['syntax'], ['google-chrome'], ['apache'], ['database-design'], ['excel'], ['amazon-web-services'], ['functional-programming'], ['url'], ['forms'], ['memory-management'], ['unicode'], ['testing'], ['emacs'], ['powershell'], ['validation'], ['sqlite'], ['events'], ['memory'], ['entity-framework'], ['networking'], ['perl'], ['caching'], ['architecture'], ['coding-style'], ['installation'], ['wcf'], ['inheritance'], ['enums']]
#
# word: tsql	nb count: 2
# word: sql-server-2005	nb count: 2
# --------------------
#
# {'tsql': [['sql-server-2005', 'sql', 'tsql'], ['sql-server', 'sql-server-2005', 'tsql']], 'sql-server-2005': [['sql-server-2005', 'sql', 'tsql'], ['sql-server', 'sql-server-2005', 'tsql']]}
# len tagsListReduced :109
# [['numpy', 'python-3.x', 'list', 'pandas', 'dictionary', 'dataframe', 'django', 'matplotlib', 'python'], ['c#', 'winforms', 'generics', 'reflection', 'linq', '.net'], ['java', 'hibernate', 'spring', 'collections'], ['javascript', 'jquery', 'dom', 'ajax'], ['c++', 'c++11', 'templates'], ['android-studio', 'android'], ['php', 'laravel'], ['html'], ['ios', 'swift', 'uitableview', 'xcode', 'ios7'], ['pointers', 'c'], ['css'], ['iphone', 'cocoa-touch'], ['github', 'git'], ['cocoa', 'objective-c'], ['mysql'], ['linux'], ['asp.net'], ['batch-file', 'windows'], ['string'], ['algorithm'], ['ruby'], ['ruby-on-rails'], ['bash'], ['asp.net-mvc'], ['performance'], ['node.js'], ['arrays'], ['database'], ['r'], ['multithreading'], ['regex'], ['wpf'], ['json'], ['visual-studio'], ['macos'], ['reactjs'], ['shell'], ['angularjs'], ['unit-testing'], ['language-agnostic'], ['eclipse'], ['oop'], ['vim'], ['xml'], ['angular'], ['svn'], ['debugging'], ['postgresql'], ['http'], ['security'], ['unix'], ['version-control'], ['design-patterns'], ['image'], ['datetime'], ['file'], ['rest'], ['docker'], ['command-line'], ['math'], ['exception'], ['typescript'], ['function'], ['twitter-bootstrap'], ['scala'], ['authentication'], ['date'], ['optimization'], ['sorting'], ['oracle'], ['logging'], ['class'], ['user-interface'], ['mongodb'], ['go'], ['data-structures'], ['gcc'], ['firebase'], ['parsing'], ['web-services'], ['syntax'], ['google-chrome'], ['apache'], ['database-design'], ['excel'], ['amazon-web-services'], ['functional-programming'], ['url'], ['forms'], ['memory-management'], ['unicode'], ['testing'], ['emacs'], ['powershell'], ['validation'], ['sqlite'], ['events'], ['memory'], ['entity-framework'], ['networking'], ['perl'], ['caching'], ['architecture'], ['coding-style'], ['installation'], ['wcf'], ['inheritance'], ['enums'], ['sql-server', 'sql-server-2005', 'sql', 'tsql']]

# %% [markdown]
# ## création diconaire de passage

# %%
#dicoWordToList : python -> ['python','dataframe','pandas'..]
#dicoPassageListToTag:  ['python','dataframe','pandas'..] -> tag0
# dicoPassageTagToList: tag0 -> ['python','dataframe','pandas'..]
tagListReduced= [tuple(i) for i in tagListReduced] #Solve unhashable type: 'list'
dicoWordToList={}
for i in tagListReduced:
    for tag in i:
        dicoWordToList.update({tag:i})
        
#listNewTag = [ ('tag'+str(ind),set(i)) for ind, i in enumerate(tagListReduced)]
nameNewTag = ["tag"+str(i) for i in range(len(tagListReduced))]
listNewTag = zip(nameNewTag,tagListReduced)

#[print(i) for i in listNewTag]

dicoPassageListToTag={liste:tag for tag, liste in listNewTag}
listNewTag = zip(nameNewTag,tagListReduced) # !????
dicoPassageTagToList={tag:liste for  tag, liste in listNewTag}
print(f" number of new Tags :{len(dicoPassageTagToList.keys())}")
# Out:
#  number of new Tags :109

# %%
data['filtered_tags_reduced'] = data['filtered_tags'].apply(lambda x : list(set([dicoPassageListToTag[dicoWordToList[i]] for i in x])))

# %%
data.head()
# Out:
#                                                                     Title  \
# 0                                  django m2m form save " through " table
# 1                              transpose/unzip function (inverse of zip)?
# 2                           detecting audio silence in wav files using c#
# 3                                     how to request a random row in sql?
# 4  mod_rewrite rule to redirect all requests except for one specific path
#
#                                                                                                                                                                                                       Body  \
# 0  <p>I'm having trouble in saving a m2m data, containing a 'through' class table.\nI want to save all selected members (selected in the form) in the through table.\nBut i don't know how to initialis...
# 1  <p>I have a list of 2-item tuples and I'd like to convert them to 2 lists where the first contains the first item in each tuple and the second list holds the second item.</p>\n\n<p><strong>For exa...
# 2  <p>I'm tasked with building a .NET client app to detect silence in a WAV files.</p>\n\n<p>Is this possible with the built-in Windows APIs? Or alternately, any good libraries out there to help with...
# 3                                                                                                        <p>How can I request a random row (or as close to truly random as is possible) in pure SQL?</p>\n
# 4  <p>I'm trying to redirect all requests to my domain to another domain using mod_rewrite in an Apache 2.2 VirtualHost declaration. There is one exception to this -- I'd like all requests  to the <c...
#
#                                 Tags  \
# 0               <django><forms><m2m>
# 1  <python><list><matrix><transpose>
# 2                  <c#><.net><audio>
# 3                      <sql><random>
# 4              <apache><mod-rewrite>
#
#                                                                                                                                                                                                       text  \
# 0  i'm having trouble in saving a m2m data, containing a 'through' class table.\ni want to save all selected members (selected in the form) in the through table.\nbut i don't know how to initialise t...
# 1  i have a list of 2-item tuples and i'd like to convert them to 2 lists where the first contains the first item in each tuple and the second list holds the second item.\nfor example:\noriginal = [(...
# 2         i'm tasked with building a .net client app to detect silence in a wav files.\nis this possible with the built-in windows apis? or alternately, any good libraries out there to help with this?\n
# 3                                                                                                               how can i request a random row (or as close to truly random as is possible) in pure sql?\n
# 4  i'm trying to redirect all requests to my domain to another domain using mod_rewrite in an apache 2.2 virtualhost declaration. there is one exception to this -- i'd like all requests  to the /audi...
#
#    nb_char  \
# 0     1442
# 1      350
# 2      190
# 3       89
# 4     1990
#
#                                                                                                                                                                                                     tokens  \
# 0  [i, m, having, trouble, in, saving, a, m2m, data, containing, a, through, class, table, i, want, to, save, all, selected, members, selected, in, the, form, in, the, through, table, but, i, don, t,...
# 1  [i, have, a, list, of, 2, item, tuples, and, i, d, like, to, convert, them, to, 2, lists, where, the, first, contains, the, first, item, in, each, tuple, and, the, second, list, holds, the, second...
# 2  [i, m, tasked, with, building, a, net, client, app, to, detect, silence, in, a, wav, files, is, this, possible, with, the, built, in, windows, apis, or, alternately, any, good, libraries, out, the...
# 3                                                                                                [how, can, i, request, a, random, row, or, as, close, to, truly, random, as, is, possible, in, pure, sql]
# 4  [i, m, trying, to, redirect, all, requests, to, my, domain, to, another, domain, using, mod, rewrite, in, an, apache, 2, 2, virtualhost, declaration, there, is, one, exception, to, this, i, d, lik...
#
#                                                                           tokens_title  \
# 0                                            [django, m2m, form, save, through, table]
# 1                                       [transpose, unzip, function, inverse, of, zip]
# 2                               [detecting, audio, silence, in, wav, files, using, c#]
# 3                                          [how, to, request, a, random, row, in, sql]
# 4  [mod, rewrite, rule, to, redirect, all, requests, except, for, one, specific, path]
#
#    nb_tokens  \
# 0        188
# 1         70
# 2         36
# 3         19
# 4        314
#
#                                                                                                                                                                                              tokens_unique  \
# 0  (through, foreignkey, unique, if, be, valid, default, know, containing, classname, want, name, trouble, m, data, how, new, code, 140, creator, is, right, model, don, instance, method, booleanfield...
# 1  (have, d, list, and, result, to, lists, c, convert, second, example, 2, for, original, 4, holds, want, builtin, #, there, item, them, that, tuples, contains, where, first, in, function, does, like...
# 2         (good, tasked, silence, to, windows, app, files, this, help, alternately, any, there, is, wav, built, detect, m, in, building, possible, libraries, or, apis, out, with, a, the, i, net, client)
# 3                                                                                                            (a, row, how, i, sql, in, to, close, can, truly, request, possible, is, or, random, pure, as)
# 4  (rewriteengine, path, if, anyone, error, customlog, be, expect, perfect, work, still, sense, rewrite, contains, what, m, wrong, slash, s, requests, does, without, newdomain, 301, mod, net, is, rig...
#
#    nb_tokens_unique  \
# 0                82
# 1                42
# 2                30
# 3                17
# 4               148
#
#                                                                                                                                                                                                 tokens_WSW  \
# 0  [trouble, saving, m2m, data, containing, class, table, want, save, selected, members, selected, form, table, know, initialise, table, view, code, class, classroom, models, model, user, models, for...
# 1            [list, item, tuples, like, convert, lists, first, contains, first, item, tuple, second, list, holds, second, item, example, original, b, c, #, want, become, result, b, c, builtin, function]
# 2                                                                    [tasked, building, net, client, app, detect, silence, wav, files, possible, built, windows, apis, alternately, good, libraries, help]
# 3                                                                                                                                        [request, random, row, close, truly, random, possible, pure, sql]
# 4  [trying, redirect, requests, domain, another, domain, using, mod, rewrite, apache, virtualhost, declaration, one, exception, like, requests, audio, path, redirected, written, rewritecond, rewriter...
#
#                                                         tokens_title_WSW  \
# 0                                       [django, m2m, form, save, table]
# 1                             [transpose, unzip, function, inverse, zip]
# 2                     [detecting, audio, silence, wav, files, using, c#]
# 3                                            [request, random, row, sql]
# 4  [mod, rewrite, rule, redirect, requests, except, one, specific, path]
#
#    nb_tokens_WSW  \
# 0            141
# 1             28
# 2             17
# 3              9
# 4            191
#
#                                                                                                                                                                                               tokens_lemma  \
# 0  [trouble, save, m2, m, datum, contain, class, table, want, save, select, member, select, form, table, know, initialise, table, view, code, class, classroom, model, model, user, model, foreignkey, ...
# 1                [list, item, tuple, like, convert, list, first, contain, first, item, tuple, second, list, hold, second, item, example, original, b, c, #, want, become, result, b, c, builtin, function]
# 2                                                                             [task, build, net, client, app, detect, silence, wav, file, possible, build, window, apis, alternately, good, library, help]
# 3                                                                                                                                        [request, random, row, close, truly, random, possible, pure, sql]
# 4  [try, redirect, request, domain, another, domain, use, mod, rewrite, apache, virtualhost, declaration, one, exception, like, request, audio, path, redirect, write, rewritecond, rewriterule, quite,...
#
#    len_tokens_lemma                          Tags_list  len _Tags_list  \
# 0               142               [django, forms, m2m]               3
# 1                28  [list, transpose, matrix, python]               4
# 2                17                  [c#, audio, .net]               3
# 3                 9                      [random, sql]               2
# 4               191              [apache, mod-rewrite]               2
#
#      filtered_tags filtered_tags_reduced
# 0  [django, forms]         [tag0, tag88]
# 1   [list, python]                [tag0]
# 2       [c#, .net]                [tag1]
# 3            [sql]              [tag108]
# 4         [apache]               [tag82]

# %% [markdown]
# on regarde l'effet du regroupement sur le nombre de Tags associé à un post.

# %% [markdown]
# avant:

# %%
data['len _Tags_list'].value_counts()
# Out:
# 3    14684
# 2    11675
# 4    10726
# 5     6998
# 1     3940
# Name: len _Tags_list, dtype: int64

# %% [markdown]
# après:

# %%
dataTest = data['filtered_tags_reduced'].apply(lambda x: len(x))
data['len_filtered_tags_reduced'] = dataTest
dataTest.value_counts()
# Out:
# 1    24808
# 2    14512
# 0     4669
# 3     3552
# 4      456
# 5       26
# Name: filtered_tags_reduced, dtype: int64

# %%
5*26 + 4*456 +3*3552 + 2*14512 +24808 +4669
# Out:
# 71111

# %%
data['filtered_tags_reduced'][dataTest == 1].value_counts()
# Out:
# [tag0]      3175
# [tag1]      2403
# [tag2]      2089
# [tag3]      2047
# [tag5]      1588
# [tag4]      1161
# [tag8]       897
# [tag12]      809
# [tag6]       770
# [tag108]     678
# [tag9]       428
# [tag28]      408
# [tag11]      360
# [tag10]      342
# [tag14]      287
# [tag17]      287
# [tag19]      251
# [tag21]      249
# [tag7]       239
# [tag20]      234
# [tag15]      228
# [tag25]      227
# [tag42]      227
# [tag23]      221
# [tag16]      220
# [tag31]      196
# [tag13]      184
# [tag37]      179
# [tag22]      175
# [tag35]      165
# [tag33]      163
# [tag57]      162
# [tag44]      154
# [tag45]      141
# [tag39]      138
# [tag64]      125
# [tag74]      115
# [tag30]      113
# [tag40]      105
# [tag92]      101
# [tag85]      100
# [tag93]       98
# [tag47]       98
# [tag34]       94
# [tag73]       90
# [tag27]       90
# [tag84]       87
# [tag61]       78
# [tag43]       75
# [tag100]      73
# [tag52]       71
# [tag86]       69
# [tag49]       65
# [tag56]       63
# [tag38]       63
# [tag77]       61
# [tag59]       61
# [tag82]       56
# [tag51]       54
# [tag41]       53
# [tag69]       53
# [tag63]       52
# [tag102]      49
# [tag48]       49
# [tag46]       49
# [tag24]       48
# [tag29]       47
# [tag81]       47
# [tag36]       44
# [tag72]       44
# [tag50]       43
# [tag32]       43
# [tag104]      39
# [tag65]       38
# [tag76]       38
# [tag99]       36
# [tag98]       36
# [tag75]       32
# [tag58]       32
# [tag95]       31
# [tag105]      31
# [tag53]       30
# [tag87]       26
# [tag83]       25
# [tag80]       22
# [tag90]       22
# [tag79]       22
# [tag103]      22
# [tag91]       21
# [tag78]       19
# [tag18]       17
# [tag70]       16
# [tag67]       14
# [tag88]       14
# [tag62]       14
# [tag101]      12
# [tag55]       12
# [tag26]       12
# [tag97]       12
# [tag94]       10
# [tag89]        9
# [tag71]        6
# [tag60]        6
# [tag68]        5
# [tag96]        5
# [tag54]        4
# [tag66]        4
# [tag106]       3
# [tag107]       3
# Name: filtered_tags_reduced, dtype: int64

# %% [markdown]
# ## Multi output to single output

# %%
lenFilteredTags = data['len_filtered_tags_reduced'].value_counts().index.max()
temp=data[(data['len_filtered_tags_reduced']==1) | (data['len_filtered_tags_reduced']==0)]

for i in range(2,lenFilteredTags+1):
    temp_i = data[data['len_filtered_tags_reduced']==i]
    for j in range(0,i):
        temp2 = temp_i.loc[:]
        temp2['filtered_tags_reduced'] = temp_i['filtered_tags_reduced'].apply(lambda x: [x[j]])
        temp = pd.concat([temp, temp2], ignore_index=True)

temp.shape
# Out:
# (71111, 20)

# %%
dataTest = temp['filtered_tags_reduced'].apply(lambda x: len(x))
dataTest.value_counts()     ############################################### value count
# Out:
# 1    66442
# 0     4669
# Name: filtered_tags_reduced, dtype: int64

# %%
i= [ str(i) for i in temp['filtered_tags_reduced'].value_counts().index]
j= [ j for j in temp['filtered_tags_reduced'].value_counts()]
plt.figure(figsize=(30,11))
plt.xticks(rotation=90)
plt.title("new Tags distribution in posts") 
plt.bar(i,j)
plt.show()

# %%
temp['filtered_tags_reduced'][temp['filtered_tags_reduced'].str.len() == 0]
# Out:
# 5        []
# 10       []
# 23       []
# 27       []
# 36       []
#          ..
# 29447    []
# 29452    []
# 29453    []
# 29461    []
# 29463    []
# Name: filtered_tags_reduced, Length: 4669, dtype: object

# %%
temp['filtered_tags_reduced'] = temp['filtered_tags_reduced'].apply(lambda x : ['#empty'] if len(''.join(x)) == 0 else x)

# %%
temp['filtered_tags_reduced'][temp['filtered_tags_reduced'].str.len() == 0]
# Out:
# Series([], Name: filtered_tags_reduced, dtype: object)

# %%
temp['filtered_tags_reduced'] =temp['filtered_tags_reduced'].apply(lambda x:  x[0]) # column 'filtered_tags_reduced' list to string

# %%
temp['filtered_tags_reduced'].value_counts().index.item
# Out:
# <bound method IndexOpsMixin.item of Index(['tag1', 'tag0', 'tag3', '#empty', 'tag2', 'tag4', 'tag5', 'tag8',
#        'tag6', 'tag7',
#        ...
#        'tag98', 'tag100', 'tag99', 'tag102', 'tag101', 'tag103', 'tag104',
#        'tag106', 'tag105', 'tag107'],
#       dtype='object', length=110)>

# %%
temp['filtered_tags_reduced'].apply(lambda x: len([x])).value_counts()
# Out:
# 1    71111
# Name: filtered_tags_reduced, dtype: int64

# %%
countReducedTag = temp['filtered_tags_reduced'].value_counts().values
nbReducedTag = np.sum(countReducedTag,axis=0)
divider = np.full((len(countReducedTag),),nbReducedTag)
percentReducedTag = np.divide(countReducedTag,divider)
percentReducedTag = percentReducedTag*100 # in %
percentCumReducedTag = np.cumsum(percentReducedTag)

# %%
i= [ str(i) for i in temp['filtered_tags_reduced'].value_counts().index]
j= [ j for j in percentCumReducedTag]
plt.figure(figsize=(30,11))
plt.xticks(rotation=90)
plt.title("cumulative count of new tags in %")
plt.bar(i,j)
plt.show()

# %%
###

# %%
## Execution time to long for the models.
# remove less occuring tags
# remove 20% of the tags entry

# %%
dfpercentCumReducedTag = pd.DataFrame({'name':i, 'countCum':j})
listToFlagEmpty = dfpercentCumReducedTag['name'][dfpercentCumReducedTag['countCum']>=80].values
temp2 = temp.copy()
temp2['filtered_tags_reduced'] = temp['filtered_tags_reduced'].apply(lambda x : x if x not in listToFlagEmpty else '#empty')

# %%
len(listToFlagEmpty)
# Out:
# 69

# %%
for i in listToFlagEmpty: print(dicoPassageTagToList[i])
# Out:
# ('language-agnostic',)
# ('eclipse',)
# ('oop',)
# ('vim',)
# ('xml',)
# ('angular',)
# ('svn',)
# ('debugging',)
# ('http',)
# ('postgresql',)
# ('security',)
# ('unix',)
# ('version-control',)
# ('design-patterns',)
# ('image',)
# ('file',)
# ('datetime',)
# ('rest',)
# ('docker',)
# ('command-line',)
# ('math',)
# ('exception',)
# ('typescript',)
# ('twitter-bootstrap',)
# ('function',)
# ('scala',)
# ('authentication',)
# ('date',)
# ('sorting',)
# ('optimization',)
# ('oracle',)
# ('logging',)
# ('class',)
# ('user-interface',)
# ('mongodb',)
# ('go',)
# ('data-structures',)
# ('gcc',)
# ('firebase',)
# ('parsing',)
# ('web-services',)
# ('syntax',)
# ('google-chrome',)
# ('apache',)
# ('database-design',)
# ('excel',)
# ('amazon-web-services',)
# ('functional-programming',)
# ('url',)
# ('forms',)
# ('unicode',)
# ('memory-management',)
# ('testing',)
# ('emacs',)
# ('powershell',)
# ('validation',)
# ('sqlite',)
# ('memory',)
# ('events',)
# ('entity-framework',)
# ('perl',)
# ('networking',)
# ('architecture',)
# ('caching',)
# ('coding-style',)
# ('installation',)
# ('inheritance',)
# ('wcf',)
# ('enums',)

# %%
# test temp3 (temp2 without empty category) average F1 score too low 0.2

# %%
temp3 = temp2[temp2['filtered_tags_reduced'] != '#empty']
temp3['filtered_tags_reduced'].value_counts()
# Out:
# tag1      5224
# tag0      5202
# tag3      4675
# tag2      4283
# tag4      2547
# tag5      2198
# tag8      2055
# tag6      1724
# tag7      1649
# tag108    1564
# tag9      1354
# tag11     1259
# tag10     1222
# tag12     1126
# tag13     1055
# tag14      889
# tag15      886
# tag17      828
# tag16      812
# tag18      722
# tag19      696
# tag20      682
# tag21      649
# tag22      636
# tag23      626
# tag24      620
# tag25      597
# tag26      588
# tag27      582
# tag28      563
# tag29      477
# tag30      472
# tag31      471
# tag32      462
# tag33      446
# tag34      438
# tag35      429
# tag36      424
# tag37      389
# tag38      383
# Name: filtered_tags_reduced, dtype: int64

# %% [markdown]
# ## save data

# %%
data.dtypes
# Out:
# Title                        object
# Body                         object
# Tags                         object
# text                         object
# nb_char                       int64
# tokens                       object
# tokens_title                 object
# nb_tokens                     int64
# tokens_unique                object
# nb_tokens_unique              int64
# tokens_WSW                   object
# tokens_title_WSW             object
# nb_tokens_WSW                 int64
# tokens_lemma                 object
# len_tokens_lemma              int64
# Tags_list                    object
# len _Tags_list                int64
# filtered_tags                object
# filtered_tags_reduced        object
# len_filtered_tags_reduced     int64
# dtype: object

# %%
with open(path + 'cleanData.pickle', 'wb') as f:
    pickle.dump(data,f,pickle.HIGHEST_PROTOCOL)
    
with open(path + 'cleanDataprepSmote.pickle', 'wb') as f:
    pickle.dump(temp,f,pickle.HIGHEST_PROTOCOL)
    
with open(path + 'cleanDataprepSmote2.pickle', 'wb') as f:
    pickle.dump(temp2,f,pickle.HIGHEST_PROTOCOL)
    
with open(path + 'cleanDataprepSmote3.pickle', 'wb') as f:
    pickle.dump(temp3,f,pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## simple prediction

# %% [markdown]
# check if ones most used tokens are in the questions or titles.

# %%
dataSample = data.sample(10).reset_index()
dataSample.shape
# Out:
# (10, 21)

# %%
columnPredictedTags =  []
for text, textTitle in zip(dataSample['tokens_lemma'],dataSample['tokens_title_WSW']):
    predictedTags=[]
    for tag in nameTags:
        if tag in text or tag in textTitle:
            predictedTags.append(tag)
    columnPredictedTags.append(predictedTags)
dataSample['predicted_tags']=columnPredictedTags

# %%
dataSample.loc[:,['tokens_title_WSW','tokens_lemma','Tags_list','predicted_tags']]
# Out:
#                                                                  tokens_title_WSW  \
# 0                                       [use, oauth2, access, stackexchange, api]
# 1                                           [skip, next, iteration, jquery, util]
# 2                                               [source, code, c, c++, functions]
# 3                        [vertical, line, matching, curly, braces, java, eclipse]
# 4                                              [table, overflowing, outside, div]
# 5             [git, status, display, untracked, files, without, using, gitignore]
# 6                                              [convert, integer, string, erlang]
# 7  [system, currenttimemillis, vs, new, date, vs, calendar, getinstance, gettime]
# 8                                         [possible, recover, stackoverflowerror]
# 9                                                   [cross, site, xmlhttprequest]
#
#                                                                                                                                                                                               tokens_lemma  \
# 0  [follow, instruction, mention, https, api, stackexchange, com, docs, authentication, since, code, provide, able, understand, flow, correctly, try, get, authentication, part, do, use, two, method, ...
# 1  [try, iterate, array, element, jquery, documentation, say, jquery, documentation, return, non, false, continue, statement, loop, skip, immediately, next, iteration, try, call, return, non, false, ...
# 2                                          [want, look, implementation, different, c, c++, function, like, strcpy, stcmp, strstr, help, know, good, code, practice, c, c++, could, let, know, find, thank]
# 3                                                                [new, eclipse, ide, follow, eclipse, java, editor, configure, eclipse, show, vertical, line, match, curly, brace, java, editor, possible]
# 4  [try, stop, table, width, explicitly, declare, overflow, outside, parent, div, presume, way, use, max, width, seem, get, work, follow, code, small, window, cause, style, type, text, css, #middleco...
# 5                                                                              [git, status, display, untracked, file, without, use, gitignore, want, get, modification, status, information, track, file]
# 6                                                                   [know, strings, erlang, costly, use, convert, anything, like, io, format, p, would, return, formatted, string, instead, print, stream]
# 7  [java, performance, resource, implication, use, system, currenttimemilli, vs, new, date, vs, calendar, getinstance, gettime, understand, system, currenttimemilli, efficient, however, application, ...
# 8  [surprised, possible, continue, execution, even, stackoverflowerror, occur, java, know, stackoverflowerror, sublass, class, error, class, error, decumente, subclass, throwable, indicate, serious, ...
# 9  [want, provide, piece, javascript, code, work, website, include, always, need, get, datum, even, modify, datum, server, javascript, host, know, security, restriction, place, obvious, reason, consi...
#
#                                    Tags_list  \
# 0     [oauth-2.0, stackexchange-api, python]
# 1            [javascript, iteration, jquery]
# 2                                   [c++, c]
# 3            [syntax, java, eclipse, editor]
# 4                    [css, html-table, html]
# 5                     [version-control, git]
# 6                           [string, erlang]
# 7  [time, performance, java, calendar, date]
# 8                     [stack-overflow, java]
# 9    [javascript, xmlhttprequest, xss, ajax]
#
#                         predicted_tags
# 0            [authentication, go, url]
# 1                             [jquery]
# 2                   [c++, c, function]
# 3                      [java, eclipse]
# 4                          [css, http]
# 5                          [git, file]
# 6                             [string]
# 7            [java, performance, date]
# 8  [java, string, function, class, go]
# 9   [javascript, html, http, security]
